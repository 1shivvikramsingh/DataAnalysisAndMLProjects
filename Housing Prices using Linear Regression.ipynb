# %% [markdown]
# # Data Analysis with Python
#
# ## House Sales in King County, USA
#
# This dataset contains house sale prices for King County, which includes Seattle. It includes homes sold between May 2014 and May 2015.
#
# id : A notation for a house
#
# date: Date house was sold
#
# price: Price is prediction target
#
# bedrooms: Number of bedrooms
#
# bathrooms: Number of bathrooms
#
# sqft_living: Square footage of the home
#
# sqft_lot: Square footage of the lot
#
# floors :Total floors (levels) in house
#
# waterfront :House which has a view to a waterfront
#
# view: Has been viewed
#
# condition :How good the condition is overall
#
# grade: overall grade given to the housing unit, based on King County grading system
#
# sqft_above : Square footage of house apart from basement
#
# sqft_basement: Square footage of the basement
#
# yr_built : Built Year
#
# yr_renovated : Year when house was renovated
#
# zipcode: Zip code
#
# lat: Latitude coordinate
#
# long: Longitude coordinate
#
# sqft_living15 : Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area
#
# sqft_lot15 : LotSize area in 2015(implies-- some renovations)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import the required Dataset

# %%
link="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv"
data = pd.read_csv(link)

# %%
data.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# After  storing the dataset in a dataframe explore the data more by learning about the type of data types are stored in the dataset

# %%
data.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# Next, get to know the statistical summary of the dataset

# %%
data.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Drop the columns which are not required for the Analysis

# %%
data.drop(['id','Unnamed: 0'],axis=1, inplace=True)
data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# Check for missing values in the dataset

# %%
data.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %% [markdown]
# Replace the missing values in the column with the mean of the particular column

# %%
mean = data['bedrooms'].mean()
data['bedrooms'].replace(np.nan,mean, inplace=True)

# %%
mean = data['bathrooms'].mean()
data['bathrooms'].replace(np.nan,mean, inplace=True)

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# The data is clean and ready for Analysis

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Count the number of houses with having unique floor values

# %%
floors = data['floors'].value_counts()
floors
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
data.plot.scatter(x="floors",y="price")

# %%
data.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(16,12))
sns.heatmap(data.corr(), annot=True, linewidths=0.1)

# %%
pd.set_option('display.max_rows', None)

# %%
sorted_pairs = data.corr().unstack().sort_values()
sorted_pairs = sorted_pairs[(sorted_pairs) > 0.5]
sorted_pairs
# Out:
# floors         bathrooms        0.502132
# bathrooms      floors           0.502132
#                yr_built         0.506913
# yr_built       bathrooms        0.506913
# bedrooms       bathrooms        0.514194
# bathrooms      bedrooms         0.514194
# sqft_above     floors           0.523885
# floors         sqft_above       0.523885
# bathrooms      price            0.525738
# price          bathrooms        0.525738
# sqft_living15  bathrooms        0.569467
# bathrooms      sqft_living15    0.569467
# sqft_living    bedrooms         0.578077
# bedrooms       sqft_living      0.578077
# sqft_living15  price            0.585379
# price          sqft_living15    0.585379
# sqft_above     price            0.605567
# price          sqft_above       0.605567
# grade          bathrooms        0.664676
# bathrooms      grade            0.664676
# grade          price            0.667434
# price          grade            0.667434
# bathrooms      sqft_above       0.686309
# ...

# %%
sns.regplot(x='sqft_living',y='price', data=data)

# %%
sns.boxplot(x='waterfront',y='price', data=data)

# %%
sns.boxplot('price', data = data)

# %% [markdown]
# ## Model Development

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures

# %%
x=data[['sqft_living']]
y=data['price']
lm = LinearRegression()
lm.fit(x,y)
lm.score(x,y)
# Out:
# 0.49285321790379316

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]

# %%
x=data[features]
y=data['price']
lm = LinearRegression()
lm.fit(x,y)
lm.score(x,y)
# Out:
# 0.6576951666037494

# %%
#constructed a pipeline with an object pipe for the prediction of 'price'
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
pipe.fit(x,y)
pipe.score(x,y)
# Out:
# 0.7513404614351351

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

# %%
X = data[features]
Y = data["price"]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 3242
# number of training samples: 18371

# %%
RigeModel = Ridge(alpha=0.1) 
RigeModel.fit(x_train, y_train)
RigeModel.score(x_test, y_test)
# Out:
# 0.6478759163939115
